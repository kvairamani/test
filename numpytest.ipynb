# %% [markdown]
# <a href="https://colab.research.google.com/github/kvairamani/test/blob/master/numpytest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array([0,1,2,3,4])
b=np.array([1.3,1.4,1.5,1.6])
print(a.dtype)
print(b.dtype)
print(a.size)#array size
print(a.ndim)#array dimension
print(a)

print(a[3])
# Out:
# int64
# float64
# 5
# 1
# [0 1 2 3 4]
# 3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=np.linspace(0,2*np.pi*100)
y=np.sin(x)
plt.plot(x,y)
