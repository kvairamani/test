# %% [markdown]
# <a href="https://colab.research.google.com/github/kvairamani/test/blob/master/sinewave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plot

# sampling freq
fs = 10000

# message freq
fm = 100

# discrete frequency
w = 2 * np.pi * fm / fs

# time period
# no algo used here to find time period
N = 500

time = np.arange(0, N, 1);
amplitude = np.sin( w * time)

# plot
plot.plot(time, amplitude)

# Give a title for the sine wave plot
plot.title('Sine wave')

# Give x axis label for the sine wave plot
plot.xlabel('Time')

# Give y axis label for the sine wave plot
plot.ylabel('Amplitude = sin(time)')
plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()
